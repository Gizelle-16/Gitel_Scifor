# %% [markdown]
# <a href="https://colab.research.google.com/github/Gizelle-16/Gitel_Scifor/blob/main/plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('/content/Employee_Salary_Dataset.csv')
df.info

# %%
#bar chart
x = df['Experience_Years']
y = df['Salary']

plt.bar(x,y, color ='pink')
# Out:
# <BarContainer object of 35 artists>

# %%
#piechart
y = df['Salary']
ax=plt.subplots(1,1,figsize=(10,8))
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x7cd4c399c760>,
#   <matplotlib.patches.Wedge at 0x7cd4c39cd420>,
#   <matplotlib.patches.Wedge at 0x7cd4c37a3310>,
#   <matplotlib.patches.Wedge at 0x7cd4c37a2fb0>,
#   <matplotlib.patches.Wedge at 0x7cd4c37a18d0>,
#   <matplotlib.patches.Wedge at 0x7cd4c37a3c10>,
#   <matplotlib.patches.Wedge at 0x7cd4c37c80d0>,
#   <matplotlib.patches.Wedge at 0x7cd4c37c8550>,
#   <matplotlib.patches.Wedge at 0x7cd4c37c89d0>,
#   <matplotlib.patches.Wedge at 0x7cd4c37c8e50>,
#   <matplotlib.patches.Wedge at 0x7cd4c399c850>,
#   <matplotlib.patches.Wedge at 0x7cd4c37c9720>,
#   <matplotlib.patches.Wedge at 0x7cd4c37c9ba0>,
#   <matplotlib.patches.Wedge at 0x7cd4c37ca020>,
#   <matplotlib.patches.Wedge at 0x7cd4c37ca4a0>,
#   <matplotlib.patches.Wedge at 0x7cd4c37ca920>,
#   <matplotlib.patches.Wedge at 0x7cd4c37cada0>,
#   <matplotlib.patches.Wedge at 0x7cd4c37cb220>,
#   <matplotlib.patches.Wedge at 0x7cd4c37cb6a0>,
#   <matplotlib.patches.Wedge at 0x7cd4c37cbb20>,
#   <matplotlib.patches.Wedge at 0x7cd4c37cbfa0>,
#   <matplotlib.patches.Wedge at 0x7cd4c3804460>,
#   <matplotlib.patches.Wedge at 0x7cd4c38048e0>,
#   <matplotlib.patches.Wedge at 0x7cd4c3804d60>,
#   <matplotlib.patches.Wedge at 0x7cd4c38051e0>,
#   <matplotlib.patches.Wedge at 0x7cd4c3805660>,
#   <matplotlib.patches.Wedge at 0x7cd4c3805ae0>,
#   <matplotlib.patches.Wedge at 0x7cd4c3805f60>,
#   <matplotlib.patches.Wedge at 0x7cd4c38063e0>,
#   <matplotlib.patches.Wedge at 0x7cd4c3806860>,
#   <matplotlib.patches.Wedge at 0x7cd4c3806ce0>,
#   <matplotlib.patches.Wedge at 0x7cd4c3807160>,
#   <matplotlib.patches.Wedge at 0x7cd4c38075e0>,
#   <matplotlib.patches.Wedge at 0x7cd4c3807a60>,
#   <matplotlib.patches.Wedge at 0x7cd4c3807ee0>],
#  [Text(1.099934682839828, 0.011987221781838947, ''),
#   Text(1.099683876958717, 0.026369883523553527, ''),
#   Text(1.0993804273358103, 0.03691444149558912, ''),
#   Text(1.0990269343193855, 0.04625794678250781, ''),
#   Text(1.0989550805845423, 0.04793465194848348, ''),
#   Text(1.0624544209305282, 0.2849396487770277, ''),
#   Text(0.9573793980619689, 0.5416868912633038, ''),
#   Text(0.9376855656398904, 0.575105016488814, ''),
#   Text(0.9359137573955081, 0.5779839433045023, ''),
#   Text(0.9175404595141644, 0.6067285267354224, ''),
#   Text(0.8930375693492498, 0.6422490947683648, ''),
#   Text(0.8445748585853358, 0.7047647183603621, ''),
#   Text(0.5775973975339581, 0.9361523627925098, ''),
#   Text(0.30576478565675075, 1.0566493722386254, ''),
#   Text(0.2952666198354799, 1.0596308900796212, ''),
#   Text(0.29089916115499126, 1.0608381959749198, ''),
#   Text(0.24359988896381624, 1.0726877896652018, ''),
#   Text(-0.17698810091610906, 1.0856680948310626, ''),
#   Text(-0.5337485712918171, 0.9618276678511303, ''),
#   Text(-0.5481524151905525, 0.9536922615397297, ''),
#   Text(-0.8060865772618335, 0.7484814159071034, ''),
#   Text(-0.9852282874524164, 0.48920877097981286, ''),
#   Text(-1.0857018055405623, 0.1767811908715501, ''),
#   Text(-1.0896585825194345, -0.15047981107689162, ''),
#   Text(-1.0895606157049018, -0.1511875150425966, ''),
#   Text(-1.0893692892417857, -0.15255999363151151, ''),
#   Text(-1.0892157870285066, -0.1536521047297136, ''),
#   Text(-0.9224047672330152, -0.599307471491727, ''),
#   Text(-0.36761819490638425, -1.0367530384685506, ''),
#   Text(-0.13445129060983604, -1.0917521927861422, ''),
#   Text(-0.13035282800689663, -1.0922491200411217, ''),
#   Text(-0.08358836722169312, -1.0968194859981344, ''),
#   Text(0.033323476988403634, -1.0994951322681714, ''),
#   Text(0.5300907109201015, -0.9638484518824635, ''),
#   Text(1.0401859155711177, -0.35778940879723614, '')])

# %%
#histogram
plt.figure(figsize = (8,5))
x = df["Age"]

plt.hist(x, bins = 20, color = "purple")
plt.title("Employee ages")
plt.xlabel("Age")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#boxplot
new_data = df[["Experience_Years"]]
print(new_data.head())
plt.figure(figsize = (10, 7))
new_data.boxplot()
# Out:
#    Experience_Years
# 0                 5
# 1                 1
# 2                 3
# 3                 2
# 4                 1
# <Axes: >

# %%
#scatterplot
x =df['Experience_Years']
y =df['Salary']
plt.scatter(x,y)

# %%
#heatmap
import seaborn as sns
data = df['Gender']

plt.figure(figsize=(10, 8))
heatmap_data = df.corr()  # Assuming you want to visualize correlation
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='.2f', linewidths=1)
plt.title('Correlation Heatmap of Salary Dataset')
plt.show()
# Out:
# <ipython-input-39-21574c3e67fe>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap_data = df.corr()  # Assuming you want to visualize correlation
